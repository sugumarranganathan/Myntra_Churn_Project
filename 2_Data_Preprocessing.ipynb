# %% [markdown]
# # 2_Data_Preprocessing

# %%
import pandas as pd
import pickle
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# Load dataset
df = pd.read_csv("fashion_customer_churn.csv")

# %%
# Drop CustomerID if exists
if "CustomerID" in df.columns:
    df = df.drop("CustomerID", axis=1)

print("First 5 rows after dropping CustomerID:")
print(df.head())
# Out:
# First 5 rows after dropping CustomerID:
#    Gender  Age     City MembershipType PreferredCategory BrandPreference  \
# 0    Male   18     Pune         Silver             Women          Adidas
# 1  Female   25   Mumbai           Gold              Kids             H&M
# 2    Male   30  Chennai           Gold              Kids           Levis
# 3    Male   37     Pune           Free          Footwear          Adidas
# 4  Female   30     Pune         Silver             Women            Puma
#
#    TotalOrders  TotalSpent  AverageOrderValue  LastPurchaseDaysAgo  ...  \
# 0            9       48765            5418.33                   27  ...
# 1           49       10963             223.73                  179  ...
# 2           37       13101             354.08                   18  ...
# 3           11       30794            2799.45                   98  ...
# 4            9       16662            1851.33                  144  ...
#
#    SaleEventParticipation  ReturnCount  ExchangeCount  SizeIssueReturns  \
# 0                       0            0              1                 0
# 1                       1            6              1                 2
# 2                       6            4              7                 2
# 3                       3            0              5                 0
# 4                       3            2              8                 1
#
#    CancelCount  RefundRequests  DeliveryDelayCount  SupportTickets  \
# 0            1               4                   4               0
# 1            2               4                   2               0
# 2            1               2                   2               3
# 3            2               0                   1               5
# 4            0               0                   6               1
#
#    SatisfactionScore  Churn
# 0                3.2     No
# 1                3.9     No
# 2                3.7     No
# 3                1.9    Yes
# 4                1.6     No
#
# [5 rows x 26 columns]

# %%
# Label Encoding for categorical columns
label_encoders = {}
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

if "Churn" in categorical_cols:
    categorical_cols.remove("Churn")

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# %%
# Encode target column
target_encoder = LabelEncoder()
df["Churn"] = target_encoder.fit_transform(df["Churn"])

# Save encoders
pickle.dump(label_encoders, open("fashion_rf_label_encoders.pkl", "wb"))
pickle.dump(target_encoder, open("fashion_rf_target_encoder.pkl", "wb"))

# Save preprocessed dataset
df.to_csv("preprocessed_fashion_customer_churn.csv", index=False)

# %%
print("\nPreprocessing completed successfully.")
print("Saved files:")
print("- preprocessed_fashion_customer_churn.csv")
print("- fashion_rf_label_encoders.pkl")
print("- fashion_rf_target_encoder.pkl")
# Out:
# Preprocessing completed successfully.
# Saved files:
# - preprocessed_fashion_customer_churn.csv
# - fashion_rf_label_encoders.pkl
# - fashion_rf_target_encoder.pkl
