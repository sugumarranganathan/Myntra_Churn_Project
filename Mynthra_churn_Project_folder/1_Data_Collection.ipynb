# %% [markdown]
# #1_Data_Collection

# %% [markdown]
# **Purpose:**
# Load dataset
# Show rows, columns, types
# Show missing values
# Show churn distribution

# %%
import pandas as pd
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
dataset=pd.read_csv("fashion_customer_churn.csv")

# %%
dataset
# Out:
#     CustomerID  Gender  Age       City MembershipType PreferredCategory  \
# 0        C1001    Male   18       Pune         Silver             Women
# 1        C1002  Female   25     Mumbai           Gold              Kids
# 2        C1003    Male   30    Chennai           Gold              Kids
# 3        C1004    Male   37       Pune           Free          Footwear
# 4        C1005  Female   30       Pune         Silver             Women
# ..         ...     ...  ...        ...            ...               ...
# 495      C1496  Female   25  Bangalore           Gold          Footwear
# 496      C1497  Female   29    Chennai           Free             Women
# 497      C1498  Female   29    Chennai           Gold            Beauty
# 498      C1499  Female   39    Chennai         Silver            Beauty
# 499      C1500  Female   21  Hyderabad         Silver               Men
#
#     BrandPreference  TotalOrders  TotalSpent  AverageOrderValue  ...  \
# 0            Adidas            9       48765            5418.33  ...
# 1               H&M           49       10963             223.73  ...
# 2             Levis           37       13101             354.08  ...
# 3            Adidas           11       30794            2799.45  ...
# 4              Puma            9       16662            1851.33  ...
# ..              ...          ...         ...                ...  ...
# 495            Zara           10       37652            3765.20  ...
# 496       U.S. Polo           17       31515            1853.82  ...
# 497       U.S. Polo           17       45231            2660.65  ...
# 498       U.S. Polo           42       35569             846.88  ...
# 499            Nike           31       10036             323.74  ...
#
#      SaleEventParticipation  ReturnCount  ExchangeCount  SizeIssueReturns  \
# 0                         0            0              1                 0
# 1                         1            6              1                 2
# 2                         6            4              7                 2
# 3                         3            0              5                 0
# 4                         3            2              8                 1
# ..                      ...          ...            ...               ...
# 495                       7            1              7                 1
# 496                       0            5              4                 3
# 497                       2            1              4                 1
# 498                       6            5              1                 2
# 499                       5            6              7                 1
#
#      CancelCount  RefundRequests  DeliveryDelayCount  SupportTickets  \
# 0              1               4                   4               0
# 1              2               4                   2               0
# 2              1               2                   2               3
# 3              2               0                   1               5
# 4              0               0                   6               1
# ..           ...             ...                 ...             ...
# 495            1               2                   1               1
# 496            3               4                   5               2
# 497            1               4                   3               1
# 498            2               4                   3               3
# 499            0               1                   6               0
#
#      SatisfactionScore  Churn
# 0                  3.2     No
# 1                  3.9     No
# 2                  3.7     No
# 3                  1.9    Yes
# 4                  1.6     No
# ..                 ...    ...
# 495                2.1    Yes
# 496                2.8    Yes
# 497                1.9     No
# 498                3.8     No
# 499                4.8     No
#
# [500 rows x 27 columns]

# %%
print("DATASET PREVIEW")
print("=" * 50)
print(dataset)
df = pd.read_csv("fashion_customer_churn.csv")

print("\nFirst 5 rows:")
print(df.head())

print("\nDataset Shape:", df.shape)
print("\nChurn Distribution:")
print(df["Churn"].value_counts())
# Out:
# DATASET PREVIEW
# ==================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9735/1626918565.py in <cell line: 0>()
#       1 print("DATASET PREVIEW")
#       2 print("=" * 50)
# ----> 3 print(dataset)
#       4 df = pd.read_csv("fashion_customer_churn.csv")
#       5
#
# NameError: name 'dataset' is not defined
